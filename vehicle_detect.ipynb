# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/

# %%
# !kaggle datasets download -d daudshah/vehicle-detection-dataset

# %%
import zipfile
zip_ref= zipfile.ZipFile('/content/vehicle-detection-dataset.zip')
zip_ref.extractall('/content')
zip_ref.close()

# %%
# !pip install ultralytics

# %%
from ultralytics import YOLO

# %%
model = YOLO('yolov8n.pt')

# %%
model.train(data= "data.yaml" , epochs= 30, imgsz=640)

# %%
model = YOLO('/content/runs/detect/train/weights/best.pt')

# %%
results = model.predict('/content/test/images', save= True, conf= 0.5)
